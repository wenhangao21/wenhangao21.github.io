# %%
# %cd -

# %%
# !pwd

# %%
# %cd drive/MyDrive/ams_595_python_teaching

# %% [markdown]
# # **Lecture 12 Introduction to Web Scraping with Python**

# %% [markdown]
# ## HTML Structures

# %% [markdown]
# **Hypertext Markup Language (HTML)** serves as the standard markup language for creating web documents viewable in a browser. It defines the structure of a webpage and works seamlessly with **Cascading Style Sheets (CSS)** and scripting languages like **JavaScript** to develop engaging and interactive websites. HTML is comprised of various elements that instruct the browser on how to display content. These elements are represented by **tags**.

# %% [markdown]
# - HTML provides the basic structure of web pages, defining elements like headings, paragraphs, links, images, and more. It allows developers to organize and present content effectively for web browsers. HTML elements are represented by tags, which come in pairs, such as `<tag>` and `</tag>`, with content nested in between. The first tag in a pair is the opening tag, the second tag is the closing tag. The end tag is written like the start tag, but with a slash inserted before the tag name.
#
# ![link text](https://blog.hubspot.com/hs-fs/hubfs/html-elements-diagram.png?width=650&name=html-elements-diagram.png)
#  [Source](https://blog.hubspot.com/hs-fs/hubfs/html-elements-diagram.png?width=650&name=html-elements-diagram.png)
#
# - CSS is used to style the presentation of HTML elements on a web page. It controls the layout, appearance, and design, allowing developers to customize the look and feel of the web pages. By separating the content from its presentation, CSS enhances the visual aesthetics and user experience of a website.
#
# - JavaScript is a scripting language that adds interactivity and dynamic behavior to web pages. It enables the creation of responsive features, such as interactive forms, animations, and content updates, enhancing the overall functionality of a website. JavaScript is commonly used alongside HTML and CSS to create rich and engaging web applications.

# %% [markdown]
# Here is an explanation of the basic tags of an HTML page:
#
# - `<!DOCTYPE html>`: This declaration specifies the HTML version used in the document. For modern web pages, the HTML5 doctype is commonly used.
#
# - `<html>`: This tag represents the root of an HTML document and contains two main sections: `<head>` and `<body>`.
#
# - `<head>`: This section includes metadata, such as the page title, character encoding, and links to external resources like CSS stylesheets and JavaScript files. It doesn't display content directly on the web page.
#
#   - `<title>`: The title of the web page, which is displayed in the browser's title bar or tab.
#
#   - Other elements like `<meta>`, `<link>`, and `<script>` are commonly included within the `<head>` for defining additional information or linking external resources.
#
# - `<body>`: This section contains the visible content of the web page, including text, images, videos, and other multimedia elements. It represents the main content area that users see and interact with.
#
#   - Structural elements like headings (`<h1>`, `<h2>`, etc.), paragraphs (`<p>`), and lists (`<ul>`, `<ol>`, `<li>`) are used to organize and structure the content.
#
#   - Semantic elements such as `<header>`, `<footer>`, `<nav>`, `<main>`, and `<article>` help define different parts of the page and their purposes.
#
#   - Interactive elements like `<a>` (anchor tags for hyperlinks), `<button>`, and `<input>` are used for creating links, buttons, and forms for user interaction.
#
#   - The `<div>` element in HTML is a block-level container that is commonly used to group elements for styling purposes or to create sections on a web page. It does not inherently represent any specific semantic meaning and is often styled with CSS to provide layout and structure to the content within it.

# %% [markdown]
# HTML exhibits a hierarchical (tree-like) structure facilitated by the Document Object Model (DOM), which is a across-platform and language-independent interface. Below is an illustration of a basic HTML tree for reference.
#
# <img src="https://github.com/nestauk/im-tutorials/blob/3-ysi-tutorial/figures/Web-Scraping/dom_tree.gif?raw=1">  [Source](https://github.com/nestauk/im-tutorials/blob/3-ysi-tutorial/figures/Web-Scraping/dom_tree.gif?raw=1)

# %% [markdown]
# ## Creating a HTML Page

# %%
from IPython.core.display import display, HTML

# %%
display(HTML("""
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <title>Sample HTML Page</title>
</head>
<body>
  <h1>Welcome to My Blog</h1>
  <p>This is a sample paragraph demonstrating the use of <strong>HTML</strong>.</p>
  <p>You can also create <em>italic</em> text, define <mark>highlighted</mark> sections, <b>bold</b>, <mark>mark</mark>, <ins>underline</ins>, <del>strikethrough</del>, and <i>emphasize</i> words.</p>
  <p>Here is a link to <a href="https://www.google.com">Google</a>.</p>
  <p>This paragraph has a <del>strikethrough</del> text and an <ins>underlined</ins> text.</p>
  <p style="color: blue;">You can style text in different colors.</p>
  <p>Below is a sample unordered list:</p>
  <ul>
    <li>Item 1</li>
    <li>Item 2</li>
    <li>Item 3</li>
  </ul>

   <p>Ordered list:</p>
  <ol>
    <li>A</li>
    <li>B</li>
    <li>C</li>
    <li>D</li>
  </ol>

   <form>
    <p>Enter your name: <input type="text" id="username" name="username"></p>
    <input type="button" value="Submit" onclick="displayMessage()">
  </form>

  <p id="greeting"></p>

  <script>
    function displayMessage() {
      var name = document.getElementById("username").value;
      document.getElementById("greeting").innerHTML = "Thank you, " + name + ", for visiting my page.";
    }
  </script>
</body>
</html>
"""))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>Sample HTML Page</title>
# </head>
# <body>
#   <h1>Welcome to My Blog</h1>
#   <p>This is a sample paragraph demonstrating the use of <strong>HTML</strong>.</p>
#   <p>You can also create <em>italic</em> text, define <mark>highlighted</mark> sections, <b>bold</b>, <mark>mark</mark>, <ins>underline</ins>, <del>strikethrough</del>, and <i>emphasize</i> words.</p>
#   <p>Here is a link to <a href="https://www.google.com">Google</a>.</p>
#   <p>This paragraph has a <del>strikethrough</del> text and an <ins>underlined</ins> text.</p>
#   <p style="color: blue;">You can style text in different colors.</p>
#   <p>Below is a sample unordered list:</p>
#   <ul>
#     <li>Item 1</li>
#     <li>Item 2</li>
#     <li>Item 3</li>
#   </ul>
#
#    <p>Ordered list:</p>
#   <ol>
#     <li>A</li>
#     <li>B</li>
#     <li>C</li>
#     <li>D</li>
#   </ol>
#
#    <form>
#     <p>Enter your name: <input type="text" id="username" name="username"></p>
#     <input type="button" value="Submit" onclick="displayMessage()">
#   </form>
#
#   <p id="greeting"></p>
#
#   <script>
#     function displayMessage() {
#       var name = document.getElementById("username").value;
#       document.getElementById("greeting").innerHTML = "Thank you, " + name + ", for visiting my page.";
#     }
#   </script>
# </body>
# </html>

# %% [markdown]
# ## Web Scraping with requests and BeautifulSoup

# %% [markdown]
# Web scraping is the process of extracting and parsing data from websites. It involves fetching the HTML content of a web page and then extracting specific information from it. Python offers powerful libraries such as `requests` and `BeautifulSoup` that facilitate web scraping tasks efficiently.

# %% [markdown]
# ### Using the requests Library

# %% [markdown]
# The `requests` library in Python is used for making HTTP requests. It allows users to send GET and POST requests to a URL, retrieve data from web pages, and handle HTTP response codes. Here's an example of how to use the `requests` library:

# %%
import requests

# Send a GET request to a URL
url = 'https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php'
response = requests.get(url)

# Check the status code
if response.status_code == 200:
    # Process the response
    print(response.content)
else:
    print("Failed to retrieve the webpage.")
# Out:
# b'<!DOCTYPE html><html lang="en"><head>\n   <meta charset="utf-8"></meta>\n   <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"></meta>\n   <meta name="viewport" content="width=device-width, initial-scale=1.0"></meta>\n   <title>AMS 595 | Applied Mathematics & Statistics</title><meta name="keywords" content="Applied Math, Statistics"/><meta name="description" content="Applied Math and Statistics at Stony Brook University"/><meta property="og:title" content="AMS 595 | Applied Mathematics & Statistics"/><meta property="og:description" content="Applied Math and Statistics at Stony Brook University"/><meta property="og:type" content="website"/><meta property="og:url" content="https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php"/><meta property="og:image" content="https://www.stonybrook.edu/commcms/_resources/images/branding/rays/red-rays-full-2.png"/>   <link rel="apple-touch-icon" href="/commcms/_resources/favicon/apple-touch-icon-144x144-precomposed.png"></link>\n   <link rel="icon" href="/commcms/_resources/favicon/apple-touch-icon.png"></link>\n   <meta name="msapplication-TileColor" content="#000000"></meta>\n   <meta name="msapplication-TileImage" content="/commcms/_resources/favicon/apple-touch-icon-144x144-precomposed.png"></meta><script type="text/javascript" src="/commcms/_resources/js/jquery/jquery-1.11.1.min.js"></script><script type="text/javascript" src="/commcms/_resources/js/jquery.animateNumber.min.js"></script><link rel="stylesheet" type="text/css" href="//www.stonybrook.edu/css/main.css?ver=1.4.1"></link>\n   <link rel="stylesheet" type="text/css" href="//www.stonybrook.edu/css/new-brand.css?ver=1.4.1"></link>\n   <link rel="stylesheet" type="text/css" href="//www.stonybrook.edu/css/nav.css?ver=1.4.1"></link>\n   <link rel="stylesheet" type="text/css" href="//www.stonybrook.edu/css/elements/to-top-link/to-top.css?ver=1.4.1"></link>\n   <link href="/commcms/_resources/css/main-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>\n   <link href="/commcms/_resources/css/topnav-responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>\n   <link href="/commcms/_resources/css/banner-responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>\n   <link href="/commcms/_resources/css/search-responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>\n   <link href="/commcms/_resources/css/footer.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>\n   <link href="/commcms/_resources/css/print.css?ver=1.4.1" rel="stylesheet" type="text/css" media="print"></link>\n   <link href="/commcms/_resources/css/innerpage-responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>\n   <link href="https://www.stonybrook.edu/commcms/ams/_includes/site.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>\n   <link href="/commcms/_resources/css/responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link><script type="text/javascript" src="/commcms/_resources/js/sb-v2/responsive.js?ver=1.4.1"></script><script type="text/javascript" src="/commcms/_resources/js/sb-v2/plugins.js?ver=1.4.1"></script><link href="//maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"></link>\n   <link rel="stylesheet" href="https://use.typekit.net/vtu8fxm.css"></link>\n   <link href="/commcms/_resources/plugins/owl-carousel/owl.carousel.css?ver=1.4.1" rel="stylesheet"></link>\n   <link href="/commcms/_resources/plugins/owl-carousel/owl.carousel.custom.css?ver=1.4.1" rel="stylesheet"></link>\n   <link href="/commcms/_resources/plugins/banner-buttons/banner-buttons.css?ver=1.4.1" rel="stylesheet"></link>\n   <link href="/commcms/_resources/plugins/owl-carousel/owl.theme.css?ver=1.4.1" rel="stylesheet"></link>\n   <link href="/commcms/_resources/plugins/owl-carousel/owl.transitions.css?ver=1.4.1" rel="stylesheet"></link>\n   <link href="/commcms/_resources/plugins/slick-1.8/slick.css?ver=1.4.1" rel="stylesheet"></link>\n   <link href="/commc ...

# %%
display(HTML(response.text))
# Out:
# <!DOCTYPE html><html lang="en"><head>
#    <meta charset="utf-8"></meta>
#    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"></meta>
#    <meta name="viewport" content="width=device-width, initial-scale=1.0"></meta>
#    <title>AMS 595 | Applied Mathematics & Statistics</title><meta name="keywords" content="Applied Math, Statistics"/><meta name="description" content="Applied Math and Statistics at Stony Brook University"/><meta property="og:title" content="AMS 595 | Applied Mathematics & Statistics"/><meta property="og:description" content="Applied Math and Statistics at Stony Brook University"/><meta property="og:type" content="website"/><meta property="og:url" content="https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php"/><meta property="og:image" content="https://www.stonybrook.edu/commcms/_resources/images/branding/rays/red-rays-full-2.png"/>   <link rel="apple-touch-icon" href="/commcms/_resources/favicon/apple-touch-icon-144x144-precomposed.png"></link>
#    <link rel="icon" href="/commcms/_resources/favicon/apple-touch-icon.png"></link>
#    <meta name="msapplication-TileColor" content="#000000"></meta>
#    <meta name="msapplication-TileImage" content="/commcms/_resources/favicon/apple-touch-icon-144x144-precomposed.png"></meta><script type="text/javascript" src="/commcms/_resources/js/jquery/jquery-1.11.1.min.js"></script><script type="text/javascript" src="/commcms/_resources/js/jquery.animateNumber.min.js"></script><link rel="stylesheet" type="text/css" href="//www.stonybrook.edu/css/main.css?ver=1.4.1"></link>
#    <link rel="stylesheet" type="text/css" href="//www.stonybrook.edu/css/new-brand.css?ver=1.4.1"></link>
#    <link rel="stylesheet" type="text/css" href="//www.stonybrook.edu/css/nav.css?ver=1.4.1"></link>
#    <link rel="stylesheet" type="text/css" href="//www.stonybrook.edu/css/elements/to-top-link/to-top.css?ver=1.4.1"></link>
#    <link href="/commcms/_resources/css/main-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>
#    <link href="/commcms/_resources/css/topnav-responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>
#    <link href="/commcms/_resources/css/banner-responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>
#    <link href="/commcms/_resources/css/search-responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>
#    <link href="/commcms/_resources/css/footer.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>
#    <link href="/commcms/_resources/css/print.css?ver=1.4.1" rel="stylesheet" type="text/css" media="print"></link>
#    <link href="/commcms/_resources/css/innerpage-responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>
#    <link href="https://www.stonybrook.edu/commcms/ams/_includes/site.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>
#    <link href="/commcms/_resources/css/responsive-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link><script type="text/javascript" src="/commcms/_resources/js/sb-v2/responsive.js?ver=1.4.1"></script><script type="text/javascript" src="/commcms/_resources/js/sb-v2/plugins.js?ver=1.4.1"></script><link href="//maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"></link>
#    <link rel="stylesheet" href="https://use.typekit.net/vtu8fxm.css"></link>
#    <link href="/commcms/_resources/plugins/owl-carousel/owl.carousel.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/owl-carousel/owl.carousel.custom.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/banner-buttons/banner-buttons.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/owl-carousel/owl.theme.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/owl-carousel/owl.transitions.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/slick-1.8/slick.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/slick-1.8/slick-theme.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/css/sb/filter/text-filter.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>
#    <link href="/commcms/_resources/plugins/faculty-list/faculty-list.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/tablesaw/tablesaw.bare.css?ver=1.4.1" rel="stylesheet" type="text/css" media="screen"></link>
#    <link href="/commcms/_resources/css/sb/accordion-nav/accordion-nav-v2.css?ver=1.4.1" rel="stylesheet" type="text/css"></link>
#    <link href="/commcms/_resources/plugins/tooltipster/tooltipster.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/tooltipster/themes/tooltipster-light.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/nivo-lightbox/nivo-lightbox.css?ver=1.4.1" rel="stylesheet"></link>
#    <link href="/commcms/_resources/plugins/nivo-lightbox/themes/default/custom.css?ver=1.4.1" rel="stylesheet"></link><script src="/commcms/_resources/js/sb-v2/vendor/modernizr-2.6.2-respond-1.1.0.min.js"></script><script type="text/javascript">
# 					var COMMENT_PAGE_URL ="https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php";
# 					var COMMENT_PAGE_IDENTIFIER ="f5f5c332-c70f-4f37-a531-acbbbfc37bcc";
# 					var DOMAIN ="https://www.stonybrook.edu/commcms";
# 				</script><script type="text/javascript" src="//script.crazyegg.com/pages/scripts/0003/0382.js" async="async"></script></head><body class="responsive-template new-brand" data-template-version="2" data-ou-page-path="https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php" data-ou-dirname="/ams" data-ou-site-url="https://www.stonybrook.edu/commcms/ams/">
#     <!-- Google Tag Manager -->
#     <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-P43R9T&gtm_auth=jCHsNovKQBjtTL9y_RXzMQ&gtm_preview=env-1&gtm_cookies_win=x"
#     height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl+'&gtm_auth=jCHsNovKQBjtTL9y_RXzMQ&gtm_preview=env-1&gtm_cookies_win=x';f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-P43R9T');</script>
#     <!-- End Google Tag Manager -->
#
# <!--Facebook SDK-->
# <script>
#   window.fbAsyncInit = function() {
#     FB.init({
#       appId      : '1740688096184427',
#       xfbml      : true,
#       version    : 'v4.0'
#     });
#   };
#
#   (function(d, s, id){
#      var js, fjs = d.getElementsByTagName(s)[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement(s); js.id = id;
#      js.src = "//connect.facebook.net/en_US/sdk.js";
#      fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
# </script>
#
# <!--[if lt IE 8]>
#     <p class="chromeframe">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience. Thanks!</p>
# <![endif]-->
#
#
#
# <script async="async" src="https://enroll.stonybrook.edu/ping">/**/</script>   <div id="emergency-message-container"></div>
#    <div id="main-wrapper" class="">
#       <div id="main"><a class="skip-navigation-link" href="#main-site-content" data-scroll="false" tabindex="0">Skip Navigation</a>
#          <div class="cms-site-search-wrapper clearfix">
# 	<div class="cms-site-search search-bar clearfix hide-accessible">
# 		<div class="search">
# 			<form class="form-search clearfix" action="https://www.stonybrook.edu/search" method="get" name="seek1">
# 				<label for="search-query" class="hide-accessible">Search Text</label>
# 				<input id="search-query" class="search-txt" type="search" name="q" value="" maxlength="100" placeholder="Enter search term" />
# 				<input id="site-name" type="hidden" name="site" value="" />

# %% [markdown]
# ### Using the BeautifulSoup Library

# %% [markdown]
# The `BeautifulSoup` library provides tools for scraping information from web pages. It helps parse HTML and XML documents, making it easy to extract data from complex web pages. Here's an example of how to use the `BeautifulSoup `library:

# %%
import requests
from bs4 import BeautifulSoup

# 1
url = 'https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php'
response = requests.get(url) # response contains the HTML content

# 2
soup = BeautifulSoup(response.text, 'html.parser')

# 3
ps = soup.find_all('p')

# 4
for p in ps:
    print(p.text)
# Out:
# AMS 595, Fundamentals of Computing This course provides an introduction to several modern approaches for developing computer
#                      programs and their use to solve mathematical problems. It will cover the fundamentals
#                      of programming in MATLAB, Python, and C/C++, including scripting, basic data structures,
#                      algorithms, scientific computing, performance optimization, software engineering and
#                      program development tools. No previous programming experience is required.
# Fall semester, 1-9 credits, ABCF grading
# Prerequisite:  Familiarity of linear algebra and discrete mathematics at undergraduate
#                         level are required.  No previous programming experience is required.
# Antirequisite:  AMS 561
#
# Learning Outcomes:Knowledge of the basic elements of computer programming languages. An understanding
#                      of the use of several different programming interfaces. Practical programming skills
#                      including:
# 1. Proficiency in MATLAB programming: including scripting, procedural programming,
#                      GUI, debugging, plotting, and profiling 2. Proficiency with Python programming, including scripting, object-oriented programming,
#                      and commonly used Python libraries 3. Fundamentals of programming in C/C++, including compilers, performance optimization,
#                      STL 4. Familiarity with selected program development tools 5. Best practices in scientific software engineering, including code modularization,
#                      debugging and testing, version control, and documentation, etc.

# %% [markdown]
# Complete Web Scraping Workflow:

# %% [markdown]
# 1. Use the `requests` library to fetch the HTML content of a web page.
#
# 2. Create a `BeautifulSoup` object to parse the HTML content.
#
# 3. Use the BeautifulSoup object to find specific elements based on their tags, classes, or other attributes.
#
# 4. Extract and manipulate the desired data from the web page.

# %% [markdown]
# ## Example Web Scraping Script

# %%
import requests
from bs4 import BeautifulSoup

# Example: Extracting links from a webpage
url = 'https://www.stonybrook.edu/commcms/ams/graduate/offerings.php'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
links = soup.find_all('a')  # contains all the hyperlink reference information in this webpage
for link in links:
    print(link.get('href'))
# Out:
# #main-site-content
# /commcms/ams/about/job-opportunities.php
# https://www.stonybrook.edu/
# http://www.stonybrook.edu/ceas
# https://www.stonybrook.edu/commcms/ams/
# /commcms/ams/
# /commcms/ams/about/index.php
# /commcms/ams/about/welcome-from-the-chair.php
# /commcms/ams/about/index.php
# /commcms/ams/about/leadership.php
# /commcms/ams/about/directions.php
# /commcms/ams/about/give.php
# /commcms/ams/about/job-opportunities.php
# /commcms/ams/people/index.php#CoreFaculty
# /commcms/ams/people/index.php#CoreFaculty
# /commcms/ams/graduate/_courses/ams597.php
# /commcms/ams/graduate/_courses/ams507.php
# /commcms/ams/graduate/_courses/ams580.php
# /commcms/ams/graduate/_courses/ams597.php
# /commcms/ams/graduate/_courses/ams598.php
# /commcms/ams/graduate/_courses/ams599.php
# /commcms/ams/graduate/_courses/ams603.php
# /commcms/ams/graduate/_courses/ams676.php
# /commcms/ams/graduate/_courses/ams683.php
# /commcms/ams/graduate/_courses/ams691.php
# /commcms/ams/graduate/_courses/ams698.php
# /commcms/ams/graduate/_courses/ams699.php
# /commcms/ams/graduate/_courses/ams700.php
# /commcms/ams/graduate/_courses/ams701.php
# /commcms/ams/graduate/_courses/ams800.php
# https://www.facebook.com/groups/590688924955246/?__xts__[0]=68.ARCvE_y0FgBp9Fdd5T_Ta98oN5HQ3nAz0jXixcQte8gY5WHFeFZZMW-9gOTyk7XrPnJdwHZkdPUYU8cwUuWd_V8OnXnmRkbNBJt319EbeTR3tvYtFc11zVz7ff_ARZR96VkueK9RMh0kJlVrBQ5cOx2HN_EHzHH5ZR5JeaG6OL7PnZj696SMZWuUBuVsBl7d-HTNnOTfiU7kZjMopvoqlf6_vlP2lyUpMyXFwXT3R7SkmLWz3lm6XccKHAG3vqpPTD4-qNrtHPBYT0n5JPgiRsEx50luLpUfHx1u8TSBrO7kW1PcKxGuL4UibufdtGfdVkNLsYlMhyZk3_s2mKkeky0rdC47SGUIlL0R8A
# https://twitter.com/AmsBrook
# https://www.linkedin.com/groups/13540303/
# javascript:window.print()
# https://docs.google.com/forms/d/e/1FAIpQLScW_Uc4kfzvlKlgwoJCHSJ2EG_6bd-LjcHowxnNGKV0309uxg/viewform?gxids=7628
# http://a.cms.omniupdate.com/10?skin=oucampus&account=suny-stonybrook&site=sbcms&action=de&path=/ams/graduate/offerings.pcf
# https://www.stonybrook.edu/

# %% [markdown]
# We also want to see the title of pages

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Example 1: Extracting links and their titles from a webpage
url = 'https://www.stonybrook.edu/commcms/ams/graduate/offerings.php'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
links = soup.find_all('a')
for link in links:    # link.text is the title of the webpage and link.get('href') gives the path of the reference
    print(f"Title: {link.text}, Link: {link.get('href')}")
# Out:
# Title: Skip Navigation, Link: #main-site-content
# Title: Job Opportunities, Link: /commcms/ams/about/job-opportunities.php
# Title: , Link: https://www.stonybrook.edu/
# Title: College of Engineering and Applied Sciences, Link: http://www.stonybrook.edu/ceas
# Title: Applied Mathematics & Statistics, Link: https://www.stonybrook.edu/commcms/ams/
# Title: Home, Link: /commcms/ams/
# Title: About Us, Link: /commcms/ams/about/index.php
# Title: Welcome from the Chair, Link: /commcms/ams/about/welcome-from-the-chair.php
# Title: Overview, Link: /commcms/ams/about/index.php
# Title: Leadership, Link: /commcms/ams/about/leadership.php
# Title: Directions, Link: /commcms/ams/about/directions.php
# Title: Giving Back, Link: /commcms/ams/about/give.php
# Title: Job Opportunities, Link: /commcms/ams/about/job-opportunities.php
# Title: People, Link: /commcms/ams/people/index.php#CoreFaculty
# Title: Faculty, Link: /commcms/ams/people/index.php#CoreFaculty
# Title: print, Link: javascript:window.print()
# Title: Report an accessibility barrier, Link: https://docs.google.com/forms/d/e/1FAIpQLScW_Uc4kfzvlKlgwoJCHSJ2EG_6bd-LjcHowxnNGKV0309uxg/viewform?gxids=7628
# Title: ©Admin Login, Link: http://a.cms.omniupdate.com/10?skin=oucampus&account=suny-stonybrook&site=sbcms&action=de&path=/ams/graduate/offerings.pcf
# Title: Stony Brook University, Link: https://www.stonybrook.edu/

# %% [markdown]
# Some of the links are displayed as relative paths (/commcms/ams/graduate/_courses/ams526.php) because the get('href') method returns the href attribute as it appears in the HTML, without the domain name included. To display the complete absolute URLs, we can join the base URL of the webpage with the href attribute.
#
# However, some of the links are already complete URLs and we want to preserve them as they are, we can add a condition to check if the href is already a complete URL.

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

url = 'https://www.stonybrook.edu/commcms/ams/graduate/offerings.php'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
links = soup.find_all('a')
for link in links:
    href = link.get('href')
    absolute_link = urljoin(url, href) if not href.startswith('http') else href
    print(f"Title: {link.text}, Link: {absolute_link}")
# Out:
# Title: Skip Navigation, Link: https://www.stonybrook.edu/commcms/ams/graduate/offerings.php#main-site-content
# Title: Job Opportunities, Link: https://www.stonybrook.edu/commcms/ams/about/job-opportunities.php
# Title: , Link: https://www.stonybrook.edu/
# Title: College of Engineering and Applied Sciences, Link: http://www.stonybrook.edu/ceas
# Title: Applied Mathematics & Statistics, Link: https://www.stonybrook.edu/commcms/ams/
# Title: Home, Link: https://www.stonybrook.edu/commcms/ams/
# Title: About Us, Link: https://www.stonybrook.edu/commcms/ams/about/index.php
# Title: Welcome from the Chair, Link: https://www.stonybrook.edu/commcms/ams/about/welcome-from-the-chair.php
# Title: Overview, Link: https://www.stonybrook.edu/commcms/ams/about/index.php
# Title: Leadership, Link: https://www.stonybrook.edu/commcms/ams/about/leadership.php
# Title: Directions, Link: https://www.stonybrook.edu/commcms/ams/about/directions.php
# Title: Giving Back, Link: https://www.stonybrook.edu/commcms/ams/about/give.php
# Title: Job Opportunities, Link: https://www.stonybrook.edu/commcms/ams/about/job-opportunities.php
# Title: People, Link: https://www.stonybrook.edu/commcms/ams/people/index.php#CoreFaculty
# Title: Faculty, Link: https://www.stonybrook.edu/commcms/ams/people/index.php#CoreFaculty
# Title: Affiliated Faculty, Link: https://www.stonybrook.edu/commcms/ams/people/affiliatedfaculty.php
# Title: Postdocs, Link: https://www.stonybrook.edu/commcms/ams/people/postdoc.php
# Title: Staff, Link: https://www.stonybrook.edu/commcms/ams/people/staff.php
# Title: Graduate Students, Link: https://www.stonybrook.edu/commcms/ams/people/grad-students.php
# Title: AMS Alumnus News & Events, Link: https://www.stonybrook.edu/commcms/ams/people/ams-alumnus.php
# Title: Undergrad, Link: https://www.stonybrook.edu/commcms/ams/undergraduate/index.php
# Title: Undergraduate Program, Link: https://www.stonybrook.edu/commcms/ams/undergraduate/index.php
# Title: Course Offerings, Link: https://www.stonybrook.edu/commcms/ams/undergraduate/course-offerings.php
# Title: Course Schedules, Link: https://www.stonybrook.edu/commcms/ams/undergraduate/schedules.php
# Title: Actuarial Training, Link: https://www.stonybrook.edu/commcms/ams/undergraduate/actuary.php
# Title: Graduate, Link: https://www.stonybrook.edu/commcms/ams/graduate/index.php
# Title: Graduate Program, Link: https://www.stonybrook.edu/commcms/ams/graduate/index.php
# Title: Course Offerings, Link: https://www.stonybrook.edu/commcms/ams/graduate/offerings.php
# Title: Course Schedules, Link: https://www.stonybrook.edu/commcms/ams/graduate/sched.php
# Title: Research, Link: https://www.stonybrook.edu/commcms/ams/research/index.php
# Title: Computational Applied Mathematics, Link: https://www.stonybrook.edu/commcms/ams/research/appliedmath.php
# Title: Computational Biology, Link: https://www.stonybrook.edu/commcms/ams/research/bio.php
# Title: Operations Research, Link: https://www.stonybrook.edu/commcms/ams/research/opresearch.php
# Title: Quantitative Finance, Link: https://www.stonybrook.edu/commcms/ams/graduate/qf/research.php
# Title: Statistics, Link: https://www.stonybrook.edu/commcms/ams/research/stats.php
# Title: Data Science, Link: https://www.stonybrook.edu/commcms/ams/graduate/_datascience.php
# Title: Research Affiliations, Link: https://www.stonybrook.edu/commcms/ams/research/research-affiliations.php
# Title: Helpful Links, Link: https://www.stonybrook.edu/commcms/ams/links/index.php
# Title: Off Campus, Link: https://www.stonybrook.edu/commcms/ams/links/index.php
# Title: On Campus, Link: https://www.stonybrook.edu/commcms/ams/links/campus.php
# Title: Home, Link: https://www.stonybrook.edu/commcms/ams/
# Title: Graduate Program, Link: https://www.stonybrook.edu/commcms/ams/graduate/
# Title: Course Offerings, Link: https://www.stonybrook.edu/commcms/ams/graduate/offerings
# Title: AMS 500 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams500.php
# Title: AMS 501 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams501.php
# Title: AMS 501, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams501.php
# Title: AMS 502 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams502.php
# Title: AMS 503 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams503.php
# Title: AMS 504 Webpage, Link: http://www.stonybrook.edu/commcms/ams/graduate/_courses/ams504.php
# Title: AMS 505 Webpage , Link: http://www.stonybrook.edu/commcms/ams/graduate/_courses/ams505.php
# Title: AMS 506 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams506.php
# Title: AMS 507 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 510 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php
# Title: AMS 511 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php
# Title: AMS 511, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php
# Title: AMS 512 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 511, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php
# Title: AMS 513 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams513.php
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 513, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams513.php
# Title: AMS 514 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams514.php
# Title: AMS 515 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams515.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 516 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams516.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 511, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php
# Title: AMS 517 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams517.php
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 516, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams516.php
# Title: AMS 522, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams522.php
# Title: AMS 518 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams518.php
# Title: AMS 519 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams519.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 595, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php
# Title: AMS 561, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams561.php
# Title: AMS 520 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams520.php
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 522 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams522.php
# Title: AMS 523 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams523.php
# Title: AMS 524 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams524.php
# Title: AMS 525 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams525.php
# Title: AMS 510, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php
# Title: AMS 595, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php
# Title: AMS 526 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams526.php
# Title: AMS 527 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams527.php
# Title: AMS 528 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams528.php
# Title: AMS 530 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams530.php
# Title: AMS 531 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams531.php
# Title: AMS 532 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams532.php
# Title: AMS 533 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams533.php
# Title: AMS 534 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams534.php
# Title: AMS 535 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams535.php
# Title: AMS 536 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams536.php
# Title: AMS 537 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams537.php
# Title: AMS 539 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams539.php
# Title: AMS 540 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams540.php
# Title: AMS 542 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams542.php
# Title: AMS 544 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams544.php
# Title: AMS 545 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams545.php
# Title: AMS 546 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams546.php
# Title: AMS 547 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams547.php
# Title: AMS 548 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams548.php
# Title: AMS 549 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams549.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 550 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams550.php
# Title: AMS 552 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams552.php
# Title: AMS 553 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams553.php
# Title: AMS 554 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams554.php
# Title: AMS 555 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams555.php
# Title: AMS 507 , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 556 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams556.php
# Title: AMS 559 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams559.php
# Title: AMS 560 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams560.php
# Title: AMS 595, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php
# Title: AMS 561 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams561.php
# Title: AMS 562 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams562.php
# Title: AMS 565 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams565.php
# Title: AMS 510, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php
# Title: AMS 566 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams566.php
# Title: AMS 510, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php
# Title: AMS 569 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams569.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 570 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams570.php
# Title: AMS 570, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams570.php
# Title: AMS 571 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams571.php
# Title: AMS 572 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 573 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams573.php
# Title: AMS 575 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams575.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 578, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams578.php
# Title: AMS 577 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams577.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 578 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams578.php
# Title: AMS 580 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams580.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 582 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams582.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 578, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams578.php
# Title: AMS 583 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams583.php
# Title: AMS 585 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams585.php
# Title: AMS 570, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams570.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 586 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams586.php
# Title: AMS 412, Link: https://www.stonybrook.edu/commcms/ams/undergraduate/_courses/ams412.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 587 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams587.php
# Title: AMS 588 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams588.php
# Title: AMS 589 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams589.php
# Title: AMS 591 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams591.php
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 593 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams593.php
# Title: AMS 561, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams561.php
# Title: AMS 595 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php
# Title: AMS 596 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams596.php
# Title: AMS 597 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams597.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 580, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams580.php
# Title: AMS 597, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams597.php
# Title: AMS 598 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams598.php
# Title: AMS 599 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams599.php
# Title: AMS 603 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams603.php
# Title: AMS 676 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams676.php
# Title: AMS 683 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams683.php
# Title: AMS 691 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams691.php
# Title: AMS 698 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams698.php
# Title: AMS 699 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams699.php
# Title: AMS 700 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams700.php
# Title: AMS 701 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams701.php
# Title: AMS 800 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams800.php
# Title: Facebook, Link: https://www.facebook.com/groups/590688924955246/?__xts__[0]=68.ARCvE_y0FgBp9Fdd5T_Ta98oN5HQ3nAz0jXixcQte8gY5WHFeFZZMW-9gOTyk7XrPnJdwHZkdPUYU8cwUuWd_V8OnXnmRkbNBJt319EbeTR3tvYtFc11zVz7ff_ARZR96VkueK9RMh0kJlVrBQ5cOx2HN_EHzHH5ZR5JeaG6OL7PnZj696SMZWuUBuVsBl7d-HTNnOTfiU7kZjMopvoqlf6_vlP2lyUpMyXFwXT3R7SkmLWz3lm6XccKHAG3vqpPTD4-qNrtHPBYT0n5JPgiRsEx50luLpUfHx1u8TSBrO7kW1PcKxGuL4UibufdtGfdVkNLsYlMhyZk3_s2mKkeky0rdC47SGUIlL0R8A
# Title: Twitter, Link: https://twitter.com/AmsBrook
# Title: linkedin, Link: https://www.linkedin.com/groups/13540303/
# Title: print, Link: javascript:window.print()
# Title: Report an accessibility barrier, Link: https://docs.google.com/forms/d/e/1FAIpQLScW_Uc4kfzvlKlgwoJCHSJ2EG_6bd-LjcHowxnNGKV0309uxg/viewform?gxids=7628
# Title: ©Admin Login, Link: http://a.cms.omniupdate.com/10?skin=oucampus&account=suny-stonybrook&site=sbcms&action=de&path=/ams/graduate/offerings.pcf
# Title: Stony Brook University, Link: https://www.stonybrook.edu/

# %% [markdown]
# Now, I only want to get the tiles and links for webpages of the graduate courses that are offered. We can use a regular expression to match the pattern of three letters followed by a space and then three numbers (and possibly more texts after it, such as " Webpage".

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re

url = 'https://www.stonybrook.edu/commcms/ams/graduate/offerings.php'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
links = soup.find_all('a')
pattern = re.compile(r'^[A-Z]{3}\s\d{3}')  # Pattern for three letters, a space, and three digits
for link in links:
    if pattern.match(link.text):
        href = link.get('href')
        absolute_link = urljoin(url, href) if not href.startswith('http') else href
        print(f"Title: {link.text}, Link: {absolute_link}")
# Out:
# Title: AMS 500 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams500.php
# Title: AMS 501 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams501.php
# Title: AMS 501, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams501.php
# Title: AMS 502 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams502.php
# Title: AMS 503 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams503.php
# Title: AMS 504 Webpage, Link: http://www.stonybrook.edu/commcms/ams/graduate/_courses/ams504.php
# Title: AMS 505 Webpage , Link: http://www.stonybrook.edu/commcms/ams/graduate/_courses/ams505.php
# Title: AMS 506 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams506.php
# Title: AMS 507 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 510 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php
# Title: AMS 511 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php
# Title: AMS 511, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php
# Title: AMS 512 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 511, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php
# Title: AMS 513 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams513.php
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 513, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams513.php
# Title: AMS 514 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams514.php
# Title: AMS 515 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams515.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 516 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams516.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 511, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php
# Title: AMS 517 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams517.php
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 516, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams516.php
# Title: AMS 522, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams522.php
# Title: AMS 518 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams518.php
# Title: AMS 519 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams519.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 595, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php
# Title: AMS 561, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams561.php
# Title: AMS 520 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams520.php
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 522 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams522.php
# Title: AMS 523 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams523.php
# Title: AMS 524 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams524.php
# Title: AMS 525 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams525.php
# Title: AMS 510, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php
# Title: AMS 595, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php
# Title: AMS 526 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams526.php
# Title: AMS 527 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams527.php
# Title: AMS 528 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams528.php
# Title: AMS 530 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams530.php
# Title: AMS 531 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams531.php
# Title: AMS 532 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams532.php
# Title: AMS 533 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams533.php
# Title: AMS 534 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams534.php
# Title: AMS 535 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams535.php
# Title: AMS 536 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams536.php
# Title: AMS 537 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams537.php
# Title: AMS 539 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams539.php
# Title: AMS 540 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams540.php
# Title: AMS 542 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams542.php
# Title: AMS 544 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams544.php
# Title: AMS 545 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams545.php
# Title: AMS 546 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams546.php
# Title: AMS 547 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams547.php
# Title: AMS 548 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams548.php
# Title: AMS 549 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams549.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 550 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams550.php
# Title: AMS 552 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams552.php
# Title: AMS 553 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams553.php
# Title: AMS 554 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams554.php
# Title: AMS 555 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams555.php
# Title: AMS 507 , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 556 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams556.php
# Title: AMS 559 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams559.php
# Title: AMS 560 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams560.php
# Title: AMS 595, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php
# Title: AMS 561 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams561.php
# Title: AMS 562 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams562.php
# Title: AMS 565 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams565.php
# Title: AMS 510, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php
# Title: AMS 566 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams566.php
# Title: AMS 510, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php
# Title: AMS 569 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams569.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 570 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams570.php
# Title: AMS 570, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams570.php
# Title: AMS 571 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams571.php
# Title: AMS 572 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 573 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams573.php
# Title: AMS 575 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams575.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 578, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams578.php
# Title: AMS 577 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams577.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 578 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams578.php
# Title: AMS 580 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams580.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 582 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams582.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 578, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams578.php
# Title: AMS 583 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams583.php
# Title: AMS 585 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams585.php
# Title: AMS 570, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams570.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 586 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams586.php
# Title: AMS 412, Link: https://www.stonybrook.edu/commcms/ams/undergraduate/_courses/ams412.php
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php
# Title: AMS 587 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams587.php
# Title: AMS 588 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams588.php
# Title: AMS 589 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams589.php
# Title: AMS 591 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams591.php
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php
# Title: AMS 593 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams593.php
# Title: AMS 561, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams561.php
# Title: AMS 595 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php
# Title: AMS 596 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams596.php
# Title: AMS 597 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams597.php
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php
# Title: AMS 580, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams580.php
# Title: AMS 597, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams597.php
# Title: AMS 598 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams598.php
# Title: AMS 599 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams599.php
# Title: AMS 603 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams603.php
# Title: AMS 676 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams676.php
# Title: AMS 683 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams683.php
# Title: AMS 691 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams691.php
# Title: AMS 698 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams698.php
# Title: AMS 699 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams699.php
# Title: AMS 700 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams700.php
# Title: AMS 701 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams701.php
# Title: AMS 800 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams800.php

# %% [markdown]
# Now, we have a list of course titles and course websites, we want to get the information about the textbooks.

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re

base_url = 'https://www.stonybrook.edu/commcms/ams/graduate/offerings.php'  # Replace this with the base URL of the target website
response = requests.get(base_url)
soup = BeautifulSoup(response.text, 'html.parser')
links = soup.find_all('a', href=True)

pattern_title = re.compile(r'^[A-Z]{3}\s\d{3}')  # Pattern for three letters, a space, and three digits
pattern_ISBN = re.compile(r'ISBN(?:-1[03])?:?\s.*\d\s')

for link in links:
    if pattern_title.match(link.text):
        absolute_link = urljoin(base_url, link['href'])
        link_response = requests.get(absolute_link)
        link_soup = BeautifulSoup(link_response.text, 'html.parser')
        text = link_soup.get_text()
        ISBN = pattern_ISBN.findall(text)
        print(f"Title: {link.text}, Link: {absolute_link}, ISBN: {', '.join(ISBN)}")
# Out:
# Title: AMS 500 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams500.php, ISBN:
# Title: AMS 501 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams501.php, ISBN: ISBN #9780387989310
#
# Title: AMS 501, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams501.php, ISBN: ISBN #9780387989310
#
# Title: AMS 502 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams502.php, ISBN: ISBN: 978-3-319-30769-5
#
# Title: AMS 503 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams503.php, ISBN: ISBN: 978-0070006577
# , ISBN: 978-0-716728771
#
# Title: AMS 504 Webpage, Link: http://www.stonybrook.edu/commcms/ams/graduate/_courses/ams504.php, ISBN:
# Title: AMS 505 Webpage , Link: http://www.stonybrook.edu/commcms/ams/graduate/_courses/ams505.php, ISBN:
# Title: AMS 506 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams506.php, ISBN: ISBN #9780321794772
#
# Title: AMS 507 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php, ISBN: ISBN #9780134753119
# Title: AMS 510 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php, ISBN: ISBN: 9780098023276
# , ISBN:
#                      9781337275347
#
# Title: AMS 511 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php, ISBN: ISBN 9780-19-974008-6
#
# Title: AMS 511, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php, ISBN: ISBN 9780-19-974008-6
#
# Title: AMS 512 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php, ISBN: ISBN 978-3-540-22213-2 (hardcover); ISBN 978-3-642-00964-8 , ISBN 978-0-470-05316-4
# , ISBN 978-0-077-86167-4
# , ISBN 978-1400866281
#
# Title: AMS 511, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php, ISBN: ISBN 9780-19-974008-6
#
# Title: AMS 513 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams513.php, ISBN: ISBN: 978-0-387-24968-1
# , ISBN: 978-0-387-40101-0
# , ISBN: 978-3-030-41067-4
# , ISBN: 978-0-378-00451-3
# , ISBN:
#                      978-1-119-03799-6 , ISBN: 978-1-119-16791-8
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php, ISBN: ISBN 978-3-540-22213-2 (hardcover); ISBN 978-3-642-00964-8 , ISBN 978-0-470-05316-4
# , ISBN 978-0-077-86167-4
# , ISBN 978-1400866281
#
# Title: AMS 513, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams513.php, ISBN: ISBN: 978-0-387-24968-1
# , ISBN: 978-0-387-40101-0
# , ISBN: 978-3-030-41067-4
# , ISBN: 978-0-378-00451-3
# , ISBN:
#                      978-1-119-03799-6 , ISBN: 978-1-119-16791-8
# Title: AMS 514 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams514.php, ISBN: ISBN: 9781461485117
#
# Title: AMS 515 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams515.php, ISBN: ISBN: 978-1-4614-8470-7, Electronic ISBN: 978-1-4614-8471-4
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php, ISBN: ISBN #9780134753119
# Title: AMS 516 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams516.php, ISBN:
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php, ISBN: ISBN #9780134753119
# Title: AMS 511, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams511.php, ISBN: ISBN 9780-19-974008-6
#
# Title: AMS 517 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams517.php, ISBN: ISBN: 978-0691166278
# , ISBN: 978-0-387-77826-6
#
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php, ISBN: ISBN 978-3-540-22213-2 (hardcover); ISBN 978-3-642-00964-8 , ISBN 978-0-470-05316-4
# , ISBN 978-0-077-86167-4
# , ISBN 978-1400866281
#
# Title: AMS 516, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams516.php, ISBN:
# Title: AMS 522, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams522.php, ISBN: ISBN: 978-0-471-92083-0
# , ISBN: 978-3642009648
# Title: AMS 518 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams518.php, ISBN: ISBN: 978-1-4939-5325-7
# Title: AMS 519 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams519.php, ISBN:
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php, ISBN: ISBN: 9780137444267 , ISBN: 9780131465329
# Title: AMS 595, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php, ISBN:
# Title: AMS 561, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams561.php, ISBN:
# Title: AMS 520 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams520.php, ISBN: ISBN: 978-3030410674 , ISBN: 978-1-83921-771-5
# , ISBN: 978-0262193986
# , ISBN:
#                         978-1491945285
#
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php, ISBN: ISBN 978-3-540-22213-2 (hardcover); ISBN 978-3-642-00964-8 , ISBN 978-0-470-05316-4
# , ISBN 978-0-077-86167-4
# , ISBN 978-1400866281
#
# Title: AMS 522 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams522.php, ISBN: ISBN: 978-0-471-92083-0
# , ISBN: 978-3642009648
# Title: AMS 523 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams523.php, ISBN: ISBN #978-1-4704-7418-8 , ISBN #9780486611372
# , ISBN:  978-0486613888
# Title: AMS 524 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams524.php, ISBN:
# Title: AMS 525 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams525.php, ISBN:
# Title: AMS 510, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php, ISBN: ISBN: 9780098023276
# , ISBN:
#                      9781337275347
#
# Title: AMS 595, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php, ISBN:
# Title: AMS 526 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams526.php, ISBN: ISBN: 978-1-421-40794-4
# , ISBN: 978-0-898713-61-9
#
# Title: AMS 527 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams527.php, ISBN:
# Title: AMS 528 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams528.php, ISBN: ISBN 0-387-97999-1
# , ISBN 978-376-4-32723-1
#
# Title: AMS 530 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams530.php, ISBN: ISBN: 978-0-201-64865-2
#
# Title: AMS 531 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams531.php, ISBN:
# Title: AMS 532 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams532.php, ISBN:
# Title: AMS 533 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams533.php, ISBN:
# Title: AMS 534 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams534.php, ISBN: ISBN: 978-0815344674
# Title: AMS 535 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams535.php, ISBN:
# Title: AMS 536 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams536.php, ISBN:
# Title: AMS 537 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams537.php, ISBN:
# Title: AMS 539 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams539.php, ISBN:
# Title: AMS 540 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams540.php, ISBN:
# Title: AMS 542 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams542.php, ISBN:
# Title: AMS 544 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams544.php, ISBN:
# Title: AMS 545 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams545.php, ISBN: ISBN: 9783540779735 , ISBN: 978-0521649765 , ISBN: 978-0691145532
# Title: AMS 546 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams546.php, ISBN: ISBN: 9780136175490
# , ISBN: 0130144002
# , ISBN: 9781107024946
#
# Title: AMS 547 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams547.php, ISBN: ISBN: 978-0-4701-70205
# Title: AMS 548 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams548.php, ISBN:
# Title: AMS 549 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams549.php, ISBN:
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php, ISBN: ISBN #9780134753119
# Title: AMS 550 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams550.php, ISBN: ISBN: 9780128143469
# Title: AMS 552 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams552.php, ISBN:
# Title: AMS 553 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams553.php, ISBN: ISBN #: 978-0-07-340132-4
# Title: AMS 554 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams554.php, ISBN:
# Title: AMS 555 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams555.php, ISBN:
# Title: AMS 507 , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php, ISBN: ISBN #9780134753119
# Title: AMS 556 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams556.php, ISBN:
# Title: AMS 559 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams559.php, ISBN:
# Title: AMS 560 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams560.php, ISBN: ISBN: 978-1617290343
#
# Title: AMS 595, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php, ISBN:
# Title: AMS 561 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams561.php, ISBN:
# Title: AMS 562 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams562.php, ISBN: ISBN: 978-0-321714114
# , ISBN:
#                      978-1-491903995
#
# Title: AMS 565 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams565.php, ISBN: ISBN: 9780471359425
#
# Title: AMS 510, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php, ISBN: ISBN: 9780098023276
# , ISBN:
#                      9781337275347
#
# Title: AMS 566 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams566.php, ISBN:
# Title: AMS 510, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams510.php, ISBN: ISBN: 9780098023276
# , ISBN:
#                      9781337275347
#
# Title: AMS 569 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams569.php, ISBN: ISBN: 978-3-642-55682-1
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php, ISBN: ISBN #9780134753119
# Title: AMS 570 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams570.php, ISBN: ISBN: 978-0-534-24312-8
#
# Title: AMS 570, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams570.php, ISBN: ISBN: 978-0-534-24312-8
#
# Title: AMS 571 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams571.php, ISBN: ISBN: 978-0-534-24312-8
# Title: AMS 572 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php, ISBN: ISBN: 9780137444267 , ISBN: 9780131465329
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php, ISBN: ISBN: 9780137444267 , ISBN: 9780131465329
# Title: AMS 573 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams573.php, ISBN: ISBN: 978-0-470-46363-5 , ISBN: 978-1-60764-664-8
# Title: AMS 575 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams575.php, ISBN:
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php, ISBN: ISBN: 9780137444267 , ISBN: 9780131465329
# Title: AMS 578, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams578.php, ISBN: ISBN: 978-1-119-57872-7
# Title: AMS 577 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams577.php, ISBN: ISBN-13: 978-0131877153 / ISBN-10: 0131877151
#
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php, ISBN: ISBN: 9780137444267 , ISBN: 9780131465329
# Title: AMS 578 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams578.php, ISBN: ISBN: 978-1-119-57872-7
# Title: AMS 580 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams580.php, ISBN: ISBN: 978-1461471370
# , ISBN: 978-0387848587
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php, ISBN: ISBN: 9780137444267 , ISBN: 9780131465329
# Title: AMS 582 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams582.php, ISBN: ISBN: 978-1119593409
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php, ISBN: ISBN: 9780137444267 , ISBN: 9780131465329
# Title: AMS 578, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams578.php, ISBN: ISBN: 978-1-119-57872-7
# Title: AMS 583 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams583.php, ISBN:
# Title: AMS 585 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams585.php, ISBN:
# Title: AMS 570, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams570.php, ISBN: ISBN: 978-0-534-24312-8
#
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php, ISBN: ISBN: 9780137444267 , ISBN: 9780131465329
# Title: AMS 586 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams586.php, ISBN: ISBN #978-0-470414354 , ISBN #978-1498795630
#
# Title: AMS 412, Link: https://www.stonybrook.edu/commcms/ams/undergraduate/_courses/ams412.php, ISBN: ISBN:  978-0-12417113-8
#
# Title: AMS 572, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams572.php, ISBN: ISBN: 9780137444267 , ISBN: 9780131465329
# Title: AMS 587 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams587.php, ISBN:
# Title: AMS 588 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams588.php, ISBN: ISBN 978-1599946405
#
# Title: AMS 589 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams589.php, ISBN:
# Title: AMS 591 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams591.php, ISBN:
# Title: AMS 512, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams512.php, ISBN: ISBN 978-3-540-22213-2 (hardcover); ISBN 978-3-642-00964-8 , ISBN 978-0-470-05316-4
# , ISBN 978-0-077-86167-4
# , ISBN 978-1400866281
#
# Title: AMS 593 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams593.php, ISBN: ISBN:  978-3540221494
#
# Title: AMS 561, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams561.php, ISBN:
# Title: AMS 595 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams595.php, ISBN:
# Title: AMS 596 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams596.php, ISBN:
# Title: AMS 597 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams597.php, ISBN: ISBN  9780387790534 , ISBN 9780387954578 , ISBN 9780470533314 , ISBN 9781584885450
# Title: AMS 507, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams507.php, ISBN: ISBN #9780134753119
# Title: AMS 580, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams580.php, ISBN: ISBN: 978-1461471370
# , ISBN: 978-0387848587
# Title: AMS 597, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams597.php, ISBN: ISBN  9780387790534 , ISBN 9780387954578 , ISBN 9780470533314 , ISBN 9781584885450
# Title: AMS 598 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams598.php, ISBN: ISBN: 9789814307604 , ISBN: 9780387848570 , ISBN: 9781107077232
# Title: AMS 599 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams599.php, ISBN:
# Title: AMS 603 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams603.php, ISBN: ISBN:  978-0521497893
# , ISBN:
#                      978-0471983897
# , ISBN: 9781119157502
# , ISBN: 9780511809781
# , ISBN: 9780691089294
# , ISBN: 9780470685068
#
# Title: AMS 676 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams676.php, ISBN:
# Title: AMS 683 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams683.php, ISBN:
# Title: AMS 691 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams691.php, ISBN:
# Title: AMS 698 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams698.php, ISBN:
# Title: AMS 699 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams699.php, ISBN:
# Title: AMS 700 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams700.php, ISBN:
# Title: AMS 701 Webpage, Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams701.php, ISBN:
# Title: AMS 800 Webpage , Link: https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams800.php, ISBN:

# %% [markdown]
# ## Yet Another Example

# %% [markdown]
# We have the capability to extract tables from a website and then leverage the full range of powerful tools available in Python to handle and process the data within these tables.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
# %matplotlib inline
url = 'https://www.stonybrook.edu/commcms/ams/graduate/_courses/ams500.php'

# %%
# Access the webpage content
r = requests.get(url)
# Parse the HTML page
soup = BeautifulSoup(r.text, 'html.parser')
# Choose the relevant table
tables = soup.find_all('table')
print(len(tables))
table = soup.find_all('table')[0]
# Out:
# 2

# %%
# Parse and store the data of every table row
lst = []
for row in table.find_all('tr'):
    s = pd.Series([data.text for data in row.find_all('td')])
    lst.append(s)

# %%
df = pd.DataFrame(lst[1:])
df.columns = lst[0]
df
# Out:
#          Class Meeting                        Faculty    Week Location
# 0      August 30, 2023                Joseph Mitchell       1   Remote
# 1    September 6, 2023                 Song WuWei Zhu       2   Remote
# 2   September 13, 2023        Pawel PolakStan Uryasev       3   Remote
# 3   September 20, 2023             Haipeng XingYan Yu       4   Remote
# 4   September 27, 2023  Eugene FeinbergRoman Samulyak       5   Remote
# 5      October 4, 2023       Xiangmin JiaoPeiFen Kuan       6   Remote
# 6     October 11, 2023       James GlimmHyunkyung Lim       7   Remote
# 7     October 18, 2023           Jiaqiao HuXiaolin Li       8   Remote
# 8     October 25, 2023  Yuefan DengEvangelos Coutsias       9   Remote
# 9     November 1, 2023                       NO CLASS  Makeup   Remote
# 10    November 8, 2023                       NO CLASS           Remote
# 11   November 15, 2023                       NO CLASS             ----
# 12   November 22, 2023                       NO CLASS             ----

# %% [markdown]
# ## Ethics in Web Scraping

# %% [markdown]
# Ethical practices in web scraping are crucial to ensure the responsible and fair acquisition of data from websites.
#
# [This website](https://towardsdatascience.com/ethics-in-web-scraping-b96b18136f01) summarizes the best practices to consider when conducting web scraping activities.

# %% [markdown]
# 1. Terms of Service and Robots.txt: Always review a website's Terms of Service and adhere to the rules outlined in the `robots.txt` file. Respect the directives provided in these documents, as they outline the permissions and restrictions for web scraping. Example: https://www.google.com/robots.txt
#
# 2. Use Legal Data: Ensure that the data you collect is legally available for scraping. Avoid scraping any confidential, proprietary, or copyrighted information that is not meant for public distribution.
#
# 3. Respect Rate Limits and Delays: Implement appropriate rate limits and delays between requests to avoid overwhelming the website's server. Excessive scraping can cause server overload and may be perceived as a denial-of-service attack.
#
# 4. Identify Yourself: Provide a valid User-Agent in your HTTP header that clearly identifies your web scraper. This helps website administrators identify the source of the traffic and reach out in case of any issues.
#
# 5. Observe Crawl Frequency: Crawl only the necessary data and avoid scraping the same website too frequently. Respect the website's bandwidth and server resources, as excessive traffic can lead to performance issues and affect the experience of other users.
#
# 6. Data Privacy and Security: Ensure that the data you collect is handled securely and is not misused or shared without consent. Respect the privacy of the users whose data you are scraping.
#
# 7. Scrape Publicly Available Data: Collect data that is publicly available and does not require authentication or bypassing security measures. Avoid using any means to bypass login screens or security measures, as it can be considered unauthorized access.
#
# 8. Transparency and Attribution: If you intend to publish or share the scraped data, provide proper attribution to the source website. Clearly mention the source of the data and any transformations or interpretations you've made.
